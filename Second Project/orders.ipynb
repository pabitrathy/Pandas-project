# %%
import pandas as pd

# %%
df = pd.read_csv("orders.csv")

# %%
df
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity  Price  \
# 0      1001          Ravi  Headphones  Electronics         2   1500
# 1      1002         Sneha    Notebook   Stationery         5     60
# 2      1003         Arjun       Mouse  Electronics         1    700
# 3      1004         Divya      Pencil   Stationery        10     10
# 4      1005          Amit      Laptop  Electronics         1  55000
#
#    Order_Date
# 0  2023-05-20
# 1  2023-04-10
# 2  2023-06-05
# 3  2023-02-18
# 4  2023-07-01

# %%
df["Total_Amount"] = (df["Quantity"] * df["Price"])

# %%
df
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity  Price  \
# 0      1001          Ravi  Headphones  Electronics         2   1500
# 1      1002         Sneha    Notebook   Stationery         5     60
# 2      1003         Arjun       Mouse  Electronics         1    700
# 3      1004         Divya      Pencil   Stationery        10     10
# 4      1005          Amit      Laptop  Electronics         1  55000
#
#    Order_Date  Total_Amount
# 0  2023-05-20          3000
# 1  2023-04-10           300
# 2  2023-06-05           700
# 3  2023-02-18           100
# 4  2023-07-01         55000

# %%
[df.groupby("Category")["Quantity"].sum()]
# Out:
# [Category
#  Electronics     4
#  Stationery     15
#  Name: Quantity, dtype: int64]

# %%
df["Order_Date"] = pd.to_datetime(df["Order_Date"])
df_year = df["Order_Date"].dt.year
df_month = df["Order_Date"].dt.month

# %%
df_year
df_month
# Out:
# 0    5
# 1    4
# 2    6
# 3    2
# 4    7
# Name: Order_Date, dtype: int32

# %%
df[(df["Order_Date"].dt.year >= 2023) & (df["Order_Date"].dt.month > 3)]
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity  Price  \
# 0      1001          Ravi  Headphones  Electronics         2   1500
# 1      1002         Sneha    Notebook   Stationery         5     60
# 2      1003         Arjun       Mouse  Electronics         1    700
# 4      1005          Amit      Laptop  Electronics         1  55000
#
#   Order_Date  Total_Amount
# 0 2023-05-20          3000
# 1 2023-04-10           300
# 2 2023-06-05           700
# 4 2023-07-01         55000

# %%
df.sort_values(by = "Total_Amount", ascending = False).head(2)
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity  Price  \
# 4      1005          Amit      Laptop  Electronics         1  55000
# 0      1001          Ravi  Headphones  Electronics         2   1500
#
#   Order_Date  Total_Amount
# 4 2023-07-01         55000
# 0 2023-05-20          3000

# %%
df.sort_values(by = "Order_Date", ascending = False)
# Out:
#    Order_ID Customer_Name     Product     Category  Quantity  Price  \
# 4      1005          Amit      Laptop  Electronics         1  55000
# 2      1003         Arjun       Mouse  Electronics         1    700
# 0      1001          Ravi  Headphones  Electronics         2   1500
# 1      1002         Sneha    Notebook   Stationery         5     60
# 3      1004         Divya      Pencil   Stationery        10     10
#
#   Order_Date  Total_Amount
# 4 2023-07-01         55000
# 2 2023-06-05           700
# 0 2023-05-20          3000
# 1 2023-04-10           300
# 3 2023-02-18           100
